# %%
! python -m pip install pymongo==3.7.2
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting pymongo==3.7.2
#   Downloading pymongo-3.7.2.tar.gz (628 kB)
#      |████████████████████████████████| 628 kB 3.6 MB/s
# Building wheels for collected packages: pymongo
#   Building wheel for pymongo (setup.py) ... done
#   Created wheel for pymongo: filename=pymongo-3.7.2-cp38-cp38-linux_x86_64.whl size=415811 sha256=4894983ae3740becf472933e44402241a12c94fd6291c295e42a8d7b7d048189
#   Stored in directory: /root/.cache/pip/wheels/28/62/b5/ede9674d1415d2c15c3e805e6cc7debfcdf380105da0887776
# Successfully built pymongo
# Installing collected packages: pymongo
#   Attempting uninstall: pymongo
#     Found existing installation: pymongo 4.3.3
#     Uninstalling pymongo-4.3.3:
#       Successfully uninstalled pymongo-4.3.3
# Successfully installed pymongo-3.7.2

# %%
# !pip install spacy
# !python -m spacy download en_core_web_sm
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: spacy in /usr/local/lib/python3.8/dist-packages (3.4.4)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.8/dist-packages (from spacy) (1.0.9)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.8/dist-packages (from spacy) (1.21.6)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.8/dist-packages (from spacy) (2.11.3)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.10 in /usr/local/lib/python3.8/dist-packages (from spacy) (3.0.10)
# Requirement already satisfied: thinc<8.2.0,>=8.1.0 in /usr/local/lib/python3.8/dist-packages (from spacy) (8.1.5)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.8/dist-packages (from spacy) (1.0.4)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.8/dist-packages (from spacy) (3.3.0)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /usr/local/lib/python3.8/dist-packages (from spacy) (6.3.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4 in /usr/local/lib/python3.8/dist-packages (from spacy) (1.10.2)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.8/dist-packages (from spacy) (57.4.0)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.8/dist-packages (from spacy) (2.0.7)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.8/dist-packages (from spacy) (4.64.1)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.8/dist-packages (from spacy) (2.0.8)
# Requirement already satisfied: wasabi<1.1.0,>=0.9.1 in /usr/local/lib/python3.8/dist-packages (from spacy) (0.10.1)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from spacy) (3.0.8)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.8/dist-packages (from spacy) (2.4.5)
# Requirement already satisfied: pathy>=0.3.5 in /usr/local/lib/python3.8/dist-packages (from spacy) (0.10.1)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.8/dist-packages (from spacy) (2.23.0)
# Requirement already satisfied: typer<0.8.0,>=0.3.0 in /usr/local/lib/python3.8/dist-packages (from spacy) (0.7.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.8/dist-packages (from spacy) (21.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.8/dist-packages (from packaging>=20.0->spacy) (3.0.9)
# Requirement already satisfied: typing-extensions>=4.1.0 in /usr/local/lib/python3.8/dist-packages (from pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4->spacy) (4.4.0)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (2022.12.7)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (3.0.4)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.8/dist-packages (from thinc<8.2.0,>=8.1.0->spacy) (0.7.9)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.8/dist-packages (from thinc<8.2.0,>=8.1.0->spacy) (0.0.3)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /usr/local/lib/python3.8/dist-packages (from typer<0.8.0,>=0.3.0->spacy) (7.1.2)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.8/dist-packages (from jinja2->spacy) (2.0.1)
# /usr/local/lib/python3.8/dist-packages/torch/cuda/__init__.py:497: UserWarning: Can't initialize NVML
#   warnings.warn("Can't initialize NVML")
# 2022-12-26 06:48:41.331201: E tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting en-core-web-sm==3.4.1
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.4.1/en_core_web_sm-3.4.1-py3-none-any.whl (12.8 MB)
#      |████████████████████████████████| 12.8 MB 4.1 MB/s
# Requirement already satisfied: spacy<3.5.0,>=3.4.0 in /usr/local/lib/python3.8/dist-packages (from en-core-web-sm==3.4.1) (3.4.4)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (1.0.9)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (6.3.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (21.3)
# Requirement already satisfied: pathy>=0.3.5 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (0.10.1)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (1.10.2)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (2.23.0)
# Requirement already satisfied: thinc<8.2.0,>=8.1.0 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (8.1.5)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (2.0.7)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (57.4.0)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (2.0.8)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (3.3.0)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.10 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (3.0.10)
# Requirement already satisfied: typer<0.8.0,>=0.3.0 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (0.7.0)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (3.0.8)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (2.11.3)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (1.21.6)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (4.64.1)
# Requirement already satisfied: wasabi<1.1.0,>=0.9.1 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (0.10.1)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (1.0.4)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (2.4.5)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.8/dist-packages (from packaging>=20.0->spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (3.0.9)
# Requirement already satisfied: typing-extensions>=4.1.0 in /usr/local/lib/python3.8/dist-packages (from pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4->spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (4.4.0)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (2022.12.7)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (3.0.4)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.8/dist-packages (from thinc<8.2.0,>=8.1.0->spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (0.7.9)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.8/dist-packages (from thinc<8.2.0,>=8.1.0->spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (0.0.3)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /usr/local/lib/python3.8/dist-packages (from typer<0.8.0,>=0.3.0->spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (7.1.2)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.8/dist-packages (from jinja2->spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (2.0.1)
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')

# %%
import spacy
nlp = spacy.load("en_core_web_sm")

# %%
import numpy as np
import torch
import os
import pandas as pd
import time

# %%
import datetime                            # Imports datetime library

import pymongo
from pymongo import MongoClient

uri = 'mongodb+srv://emseccomandcenter:TUXnEN09VNM1drh3@cluster0.psiqanw.mongodb.net/?retryWrites=true&w=majority'
client = MongoClient( uri )

     
db = client["webScraping"]
col=db["arpit"]

# %%
col
# Out:
# Collection(Database(MongoClient(host=['ac-3spq6ve-shard-00-00.psiqanw.mongodb.net:27017', 'ac-3spq6ve-shard-00-01.psiqanw.mongodb.net:27017', 'ac-3spq6ve-shard-00-02.psiqanw.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, retrywrites=True, w='majority', authsource='admin', replicaset='atlas-u1jwff-shard-0', tls=True), 'webScraping'), 'arpit')

# %%
print ("total docs in col:", col.count_documents( {} ))
# Out:
# total docs in col: 238

# %%
client.list_database_names()
# Out:
# ['Emsec_medium', 'test', 'webScraping', 'admin', 'local']

# %%
dfmongo = pd.DataFrame(list(col.find()))
dfmongo=dfmongo.loc[:,'Company Name':'Description']
dfmongo=dfmongo.loc[:,'Company Name':'Description']
dfmongo.head()
# Out:
#      Company Name Data Size Last Update  \
# 0        Nextlabs    298 GB  2022-10-03
# 1  Maxey Moverley    152 GB  2022-05-23
# 2             NaN       NaN         NaN
# 3             NaN       NaN         NaN
# 4             NaN       NaN         NaN
#
#                                                 Tags  \
# 0  Business services, security software & IT serv...
# 1  Electronics repair & refurbishment, technical ...
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                   Data Downlode Link  \
# 0  http://omegalock5zxwbhswbisc42o2q2i54vdulyvtqq...
# 1  http://omegalock5zxwbhswbisc42o2q2i54vdulyvtqq...
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#            Company/Organization Name             Date  \
# 0                                NaN              NaN
# 1                                NaN              NaN
# 2                        Protecmedia  Tue Dec 20 2022
# 3                     flytour.com.br  Mon Dec 19 2022
# 4  Bregman Berbert Schwartz & Gilday  Sat Dec 17 2022
#
#                                          Description
# 0                                                NaN
# 1                                                NaN
# 2  Our tools make up a complete solution that str...
# 3  Announce. Proof of the leakage. The largest co...
# 4  For more than four decades, our firm has been ...

# %%
dfmongo.isnull().sum
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.sum of      Company Name  Data Size  Last Update   Tags  Data Downlode Link  \
# 0           False      False        False  False               False
# 1           False      False        False  False               False
# 2            True       True         True   True                True
# 3            True       True         True   True                True
# 4            True       True         True   True                True
# ..            ...        ...          ...    ...                 ...
# 233          True       True         True   True                True
# 234          True       True         True   True                True
# 235          True       True         True   True                True
# 236          True       True         True   True                True
# 237          True       True         True   True                True
#
#      Company/Organization Name   Date  Description
# 0                         True   True         True
# 1                         True   True         True
# 2                        False  False        False
# 3                        False  False        False
# 4                        False  False        False
# ..                         ...    ...          ...
# 233                      False   True        False
# 234                      False   True        False
# 235                      False   True        False
# 236                      False   True        False
# 237                      False   True        False
#
# [238 rows x 8 columns]>

# %%
dfmongo.isnull
# Out:
# <bound method DataFrame.isnull of        Company Name Data Size Last Update  \
# 0          Nextlabs    298 GB  2022-10-03
# 1    Maxey Moverley    152 GB  2022-05-23
# 2               NaN       NaN         NaN
# 3               NaN       NaN         NaN
# 4               NaN       NaN         NaN
# ..              ...       ...         ...
# 233             NaN       NaN         NaN
# 234             NaN       NaN         NaN
# 235             NaN       NaN         NaN
# 236             NaN       NaN         NaN
# 237             NaN       NaN         NaN
#
#                                                   Tags  \
# 0    Business services, security software & IT serv...
# 1    Electronics repair & refurbishment, technical ...
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 233                                                NaN
# 234                                                NaN
# 235                                                NaN
# 236                                                NaN
# 237                                                NaN
#
#                                     Data Downlode Link  \
# 0    http://omegalock5zxwbhswbisc42o2q2i54vdulyvtqq...
# 1    http://omegalock5zxwbhswbisc42o2q2i54vdulyvtqq...
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 233                                                NaN
# 234                                                NaN
# 235                                                NaN
# 236                                                NaN
# 237                                                NaN
#
#              Company/Organization Name             Date  \
# 0                                  NaN              NaN
# 1                                  NaN              NaN
# 2                          Protecmedia  Tue Dec 20 2022
# 3                       flytour.com.br  Mon Dec 19 2022
# 4    Bregman Berbert Schwartz & Gilday  Sat Dec 17 2022
# ..                                 ...              ...
# 233                www.semaphorehq.com              NaN
# 234        www.ackermanplumbinginc.com              NaN
# 235            www.candcfarmsupply.com              NaN
# 236                   www.wayan.com.mx              NaN
# 237             www.artisticstairs.com              NaN
#
#                                            Description
# 0                                                  NaN
# 1                                                  NaN
# 2    Our tools make up a complete solution that str...
# 3    Announce. Proof of the leakage. The largest co...
# 4    For more than four decades, our firm has been ...
# ..                                                 ...
# 233  Semaphore Solutions IncHeadquarters: 16420 Bak...
# 234  Ackerman Plumbing IncFLORIDA LOCATION\n2011 WH...
# 235  C&C FARMERS’ SUPPLY CORP2035 TAN BARK DRIVE HA...
# 236  WAYAN NATURAL WEARBlvd. Kukulcan Local E 19, L...
# 237  Artistic Stairs & Railingsedmproduction@artist...
#
# [238 rows x 8 columns]>

# %%
dfmongo.dropna(subset=['Company/Organization Name'	])
# Out:
#     Company Name Data Size Last Update Tags Data Downlode Link  \
# 2            NaN       NaN         NaN  NaN                NaN
# 3            NaN       NaN         NaN  NaN                NaN
# 4            NaN       NaN         NaN  NaN                NaN
# 5            NaN       NaN         NaN  NaN                NaN
# 6            NaN       NaN         NaN  NaN                NaN
# 7            NaN       NaN         NaN  NaN                NaN
# 8            NaN       NaN         NaN  NaN                NaN
# 9            NaN       NaN         NaN  NaN                NaN
# 10           NaN       NaN         NaN  NaN                NaN
# 224          NaN       NaN         NaN  NaN                NaN
# 225          NaN       NaN         NaN  NaN                NaN
# 226          NaN       NaN         NaN  NaN                NaN
# 227          NaN       NaN         NaN  NaN                NaN
# 228          NaN       NaN         NaN  NaN                NaN
# 229          NaN       NaN         NaN  NaN                NaN
# 230          NaN       NaN         NaN  NaN                NaN
# 231          NaN       NaN         NaN  NaN                NaN
# 232          NaN       NaN         NaN  NaN                NaN
# 233          NaN       NaN         NaN  NaN                NaN
# 234          NaN       NaN         NaN  NaN                NaN
# 235          NaN       NaN         NaN  NaN                NaN
# 236          NaN       NaN         NaN  NaN                NaN
# 237          NaN       NaN         NaN  NaN                NaN
#
#              Company/Organization Name             Date  \
# 2                          Protecmedia  Tue Dec 20 2022
# 3                       flytour.com.br  Mon Dec 19 2022
# 4    Bregman Berbert Schwartz & Gilday  Sat Dec 17 2022
# 5                            Events DC  Thu Dec 15 2022
# 6                         V3 Companies  Mon Dec 12 2022
# 7                        Schnee Berger  Mon Dec 12 2022
# 8                   dothousehealth.org  Sat Dec 10 2022
# 9                       Aeroproductsco  Sat Dec 10 2022
# 10      TEIJIN AUTOMOTIVE TECHNOLOGIES  Fri Dec 09 2022
# 224          www.projectredirectdc.org              NaN
# 225                   www.minex.gob.gt              NaN
# 226  www.jaspercountysheriffoffice.com              NaN
# 227               www.arisaseguros.com              NaN
# 228              www.cucafresca.com.br              NaN
# 229        www.advantagedirectcare.com              NaN
# 230        www.waynefamilypractice.com              NaN
# 231                www.pacmaritime.com              NaN
# 232                 www.baltholding.eu              NaN
# 233                www.semaphorehq.com              NaN
# 234        www.ackermanplumbinginc.com              NaN
# 235            www.candcfarmsupply.com              NaN
# 236                   www.wayan.com.mx              NaN
# 237             www.artisticstairs.com              NaN
#
#                                            Description
# 2    Our tools make up a complete solution that str...
# 3    Announce. Proof of the leakage. The largest co...
# 4    For more than four decades, our firm has been ...
# 5    Events DC, the official convention and sports ...
# 6    V3 Companies can be described in many ways: Mo...
# 7    SCHNEEBERGER serves original equipment manufac...
# 8                           over 800 gigabytes of data
# 9    APC is an ISO 9001:2015 certified manufacturer...
# 10   We respect and/or protect:\n\n    fair trade\n...
# 224  PROJECT REDIRECT INC8555 16th Street, Ste. #70...
# 225  Teléfono: (502) 2410-0000Dirección: 4-17, 2A A...
# 226  106 E. Morgan Street Newton, IL 62448Brandon F...
# 227  ARISA CORREDORES DE SEGUROS\n23 calle 15-14 zo...
# 228  CUCA FRESCAHorário de Atendimento:Segunda á Se...
# 229  Advantage Direct CareAddress: 330 Peachtree St...
# 230  WAYNE FAMILY PRACTICE, ASSOC., P.C.\n330 PEACT...
# 231  Pacific Maritime Industries Corp.Address: 1790...
# 232  Baltholding OÜKopli 63A-4, Tallinn, Estonia EE...
# 233  Semaphore Solutions IncHeadquarters: 16420 Bak...
# 234  Ackerman Plumbing IncFLORIDA LOCATION\n2011 WH...
# 235  C&C FARMERS’ SUPPLY CORP2035 TAN BARK DRIVE HA...
# 236  WAYAN NATURAL WEARBlvd. Kukulcan Local E 19, L...
# 237  Artistic Stairs & Railingsedmproduction@artist...

# %%
dfmongo
# Out:
#        Company Name Data Size Last Update  \
# 0          Nextlabs    298 GB  2022-10-03
# 1    Maxey Moverley    152 GB  2022-05-23
# 2               NaN       NaN         NaN
# 3               NaN       NaN         NaN
# 4               NaN       NaN         NaN
# ..              ...       ...         ...
# 233             NaN       NaN         NaN
# 234             NaN       NaN         NaN
# 235             NaN       NaN         NaN
# 236             NaN       NaN         NaN
# 237             NaN       NaN         NaN
#
#                                                   Tags  \
# 0    Business services, security software & IT serv...
# 1    Electronics repair & refurbishment, technical ...
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 233                                                NaN
# 234                                                NaN
# 235                                                NaN
# 236                                                NaN
# 237                                                NaN
#
#                                     Data Downlode Link  \
# 0    http://omegalock5zxwbhswbisc42o2q2i54vdulyvtqq...
# 1    http://omegalock5zxwbhswbisc42o2q2i54vdulyvtqq...
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 233                                                NaN
# 234                                                NaN
# 235                                                NaN
# 236                                                NaN
# 237                                                NaN
#
#              Company/Organization Name             Date  \
# 0                                  NaN              NaN
# 1                                  NaN              NaN
# 2                          Protecmedia  Tue Dec 20 2022
# 3                       flytour.com.br  Mon Dec 19 2022
# 4    Bregman Berbert Schwartz & Gilday  Sat Dec 17 2022
# ..                                 ...              ...
# 233                www.semaphorehq.com              NaN
# 234        www.ackermanplumbinginc.com              NaN
# 235            www.candcfarmsupply.com              NaN
# 236                   www.wayan.com.mx              NaN
# 237             www.artisticstairs.com              NaN
#
#                                            Description
# 0                                                  NaN
# 1                                                  NaN
# 2    Our tools make up a complete solution that str...
# 3    Announce. Proof of the leakage. The largest co...
# 4    For more than four decades, our firm has been ...
# ..                                                 ...
# 233  Semaphore Solutions IncHeadquarters: 16420 Bak...
# 234  Ackerman Plumbing IncFLORIDA LOCATION\n2011 WH...
# 235  C&C FARMERS’ SUPPLY CORP2035 TAN BARK DRIVE HA...
# 236  WAYAN NATURAL WEARBlvd. Kukulcan Local E 19, L...
# 237  Artistic Stairs & Railingsedmproduction@artist...
#
# [238 rows x 8 columns]

# %%
import re
def removepunct(text):
  #review = re.sub('[^a-zA-Z]', ' ', str(dataset['Review Text'][i]))
  joined_filtered_sentence = re.sub(r'[^a-zA-Z0-9 ]',r'',text)
  return joined_filtered_sentence
     
dfmongo=dfmongo.astype(str)
dfmongo['Description']=dfmongo['Description'].apply(removepunct)


dfmongo.head()
# Out:
#      Company Name Data Size Last Update  \
# 0        Nextlabs    298 GB  2022-10-03
# 1  Maxey Moverley    152 GB  2022-05-23
# 2             nan       nan         nan
# 3             nan       nan         nan
# 4             nan       nan         nan
#
#                                                 Tags  \
# 0  Business services, security software & IT serv...
# 1  Electronics repair & refurbishment, technical ...
# 2                                                nan
# 3                                                nan
# 4                                                nan
#
#                                   Data Downlode Link  \
# 0  http://omegalock5zxwbhswbisc42o2q2i54vdulyvtqq...
# 1  http://omegalock5zxwbhswbisc42o2q2i54vdulyvtqq...
# 2                                                nan
# 3                                                nan
# 4                                                nan
#
#            Company/Organization Name             Date  \
# 0                                nan              nan
# 1                                nan              nan
# 2                        Protecmedia  Tue Dec 20 2022
# 3                     flytour.com.br  Mon Dec 19 2022
# 4  Bregman Berbert Schwartz & Gilday  Sat Dec 17 2022
#
#                                          Description  \
# 0                                                nan
# 1                                                nan
# 2  Our tools make up a complete solution that str...
# 3  Announce Proof of the leakage The largest corp...
# 4  For more than four decades our firm has been d...
#
#
# 0                                                nan
# 1                                                nan
# 2  Our tools make up a complete solution that str...
# 3  Announce Proof of the leakage The largest corp...
# 4  For more than four decades our firm has been d...

# %%
from spacy.lang.en.stop_words import STOP_WORDS
     


def removestopword(text): 
  sentence = nlp(text)
  notStopWords = [notStopWords.text for notStopWords in sentence if not notStopWords.is_stop]  
  joined = " ".join(notStopWords)
  return joined
     

# df['Description']=df['Description'].apply(removestopword)
dfmongo=dfmongo.astype(str)
dfmongo=dfmongo.applymap(removestopword)
dfmongo
# Out:
#        Company Name Data Size     Last Update  \
# 0          Nextlabs    298 GB  2022 - 10 - 03
# 1    Maxey Moverley    152 GB  2022 - 05 - 23
# 2               nan       nan             nan
# 3               nan       nan             nan
# 4               nan       nan             nan
# ..              ...       ...             ...
# 233             nan       nan             nan
# 234             nan       nan             nan
# 235             nan       nan             nan
# 236             nan       nan             nan
# 237             nan       nan             nan
#
#                                                   Tags  \
# 0    Business services , security software & servic...
# 1    Electronics repair & refurbishment , technical...
# 2                                                  nan
# 3                                                  nan
# 4                                                  nan
# ..                                                 ...
# 233                                                nan
# 234                                                nan
# 235                                                nan
# 236                                                nan
# 237                                                nan
#
#                                     Data Downlode Link  \
# 0    http://omegalock5zxwbhswbisc42o2q2i54vdulyvtqq...
# 1    http://omegalock5zxwbhswbisc42o2q2i54vdulyvtqq...
# 2                                                  nan
# 3                                                  nan
# 4                                                  nan
# ..                                                 ...
# 233                                                nan
# 234                                                nan
# 235                                                nan
# 236                                                nan
# 237                                                nan
#
#              Company/Organization Name             Date  \
# 0                                  nan              nan
# 1                                  nan              nan
# 2                          Protecmedia  Tue Dec 20 2022
# 3                       flytour.com.br  Mon Dec 19 2022
# 4    Bregman Berbert Schwartz & Gilday  Sat Dec 17 2022
# ..                                 ...              ...
# 233                www.semaphorehq.com              nan
# 234        www.ackermanplumbinginc.com              nan
# 235            www.candcfarmsupply.com              nan
# 236                   www.wayan.com.mx              nan
# 237             www.artisticstairs.com              nan
#
#                                            Description  \
# 0                                                  nan
# 1                                                  nan
# 2    tools complete solution streamlines management...
# 3    Announce Proof leakage largest corporate trave...
# 4    decades firm devoted serving interests clients...
# ..                                                 ...
# 233  Semaphore Solutions IncHeadquarters 16420 Bake...
# 234  Ackerman Plumbing IncFLORIDA LOCATION2011 WHIT...
# 235  CC FARMERS SUPPLY CORP2035 TAN BARK DRIVE HARR...
# 236  WAYAN NATURAL WEARBlvd Kukulcan Local E 19 La ...
# 237  Artistic Stairs   Railingsedmproductionartisti...
#
#
# 0                                                  nan
# 1                                                  nan
# 2    tools complete solution streamlines management...
# 3    Announce Proof leakage largest corporate trave...
# 4    decades firm devoted serving interests clients...
# ..                                                 ...
# 233  Semaphore Solutions IncHeadquarters 16420 Bake...
# 234  Ackerman Plumbing IncFLORIDA LOCATION2011 WHIT...
# 235  CC FARMERS SUPPLY CORP2035 TAN BARK DRIVE HARR...
# 236  WAYAN NATURAL WEARBlvd Kukulcan Local E 19 La ...
# 237  Artistic Stairs   Railingsedmproductionartisti...
#
# [238 rows x 9 columns]

# %%
def find_ORG_Ents(text):
  my_doc = nlp(text)
  entities=[i.text for i in my_doc.ents if i.label_ == 'ORG']
  result=" ".join(entities)
  return result

def find_PERSON_Ents(text):
  my_doc = nlp(text)
  entities=[i.text for i in my_doc.ents if i.label_ == 'PERSON']
  result=" ".join(entities)
  return result 
def find_DATE_Ents(text):
  my_doc = nlp(text)
  entities=[i.text for i in my_doc.ents if i.label_ == 'DATE']
  result=" ".join(entities)
  return result
def find_GPE_Ents(text):
  my_doc = nlp(text)
  entities=[i.text for i in my_doc.ents if i.label_ == 'GPE']
  result=" ".join(entities)
  return result
def find_PRODUCT_Ents(text):
  my_doc = nlp(text)
  entities=[i.text for i in my_doc.ents if (i.label_ == 'PRODUCT') ]
  result=" ".join(entities)
  return result

# %%
dfmongo['ORG'] = dfmongo['Description'].apply(find_ORG_Ents)
dfmongo['PERSON']=dfmongo['Description'].apply(find_PERSON_Ents)
dfmongo['GPE']=dfmongo['Description'].apply(find_GPE_Ents)
dfmongo['PRODUCT']=dfmongo['Description'].apply(find_PRODUCT_Ents)
dfmongo['DATE']=dfmongo['Description'].apply(find_DATE_Ents)
dfmongo.head()
# Out:
#      Company Name Data Size     Last Update  \
# 0        Nextlabs    298 GB  2022 - 10 - 03
# 1  Maxey Moverley    152 GB  2022 - 05 - 23
# 2             nan       nan             nan
# 3             nan       nan             nan
# 4             nan       nan             nan
#
#                                                 Tags  \
# 0  Business services , security software & servic...
# 1  Electronics repair & refurbishment , technical...
# 2                                                nan
# 3                                                nan
# 4                                                nan
#
#                                   Data Downlode Link  \
# 0  http://omegalock5zxwbhswbisc42o2q2i54vdulyvtqq...
# 1  http://omegalock5zxwbhswbisc42o2q2i54vdulyvtqq...
# 2                                                nan
# 3                                                nan
# 4                                                nan
#
#            Company/Organization Name             Date  \
# 0                                nan              nan
# 1                                nan              nan
# 2                        Protecmedia  Tue Dec 20 2022
# 3                     flytour.com.br  Mon Dec 19 2022
# 4  Bregman Berbert Schwartz & Gilday  Sat Dec 17 2022
#
#                                          Description  \
# 0                                                nan
# 1                                                nan
# 2  tools complete solution streamlines management...
# 3  Announce Proof leakage largest corporate trave...
# 4  decades firm devoted serving interests clients...
#
#                                                        ORG PERSON     GPE  \
# 0                                                nan                  nan
# 1                                                nan                  nan
# 2  tools complete solution streamlines management...
# 3  Announce Proof leakage largest corporate trave...               Brazil
# 4  decades firm devoted serving interests clients...  BBSG
#
#           PRODUCT     DATE
# 0
# 1
# 2
# 3  Announce Proof
# 4                  decades
